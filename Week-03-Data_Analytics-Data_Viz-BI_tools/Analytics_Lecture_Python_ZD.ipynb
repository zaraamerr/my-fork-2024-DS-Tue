# %% [markdown]
# ### Data Science vs. Business Intelligence / Data Analytics
#
# * Data analytics/BI focuses on understanding datasets and extracting insights for actionable decisions.
# * Data science involves building, cleaning, and organizing datasets, and creating predictive models.
# * Data analysts have a more narrow and specialized role, while data scientists ask broader, strategic questions.
# *  BI is focused on extracting actionable insights from data and presenting those to stakeholders

# %%
! pip install geopandas
! pip install geoplot
# Out:
# Collecting geopandas
#   Downloading geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: numpy>=1.22 in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geopandas) (1.26.0)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.9.0-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: packaging in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geopandas) (24.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geopandas) (2.1.1)
# Collecting pyproj>=3.3.0 (from geopandas)
#   Downloading pyproj-3.6.1-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.0.6-cp311-cp311-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.4.0->geopandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Collecting certifi (from pyogrio>=0.7.2->geopandas)
#   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: six>=1.5 in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
#    ---------------------------------------- 0.0/323.6 kB ? eta -:--:--
#    ------- -------------------------------- 61.4/323.6 kB 1.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 92.2/323.6 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 276.5/323.6 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 323.6/323.6 kB 2.0 MB/s eta 0:00:00
# Downloading pyogrio-0.9.0-cp311-cp311-win_amd64.whl (15.9 MB)
#    ---------------------------------------- 0.0/15.9 MB ? eta -:--:--
#     --------------------------------------- 0.2/15.9 MB 4.6 MB/s eta 0:00:04
#    - -------------------------------------- 0.4/15.9 MB 5.3 MB/s eta 0:00:03
#    - -------------------------------------- 0.7/15.9 MB 4.8 MB/s eta 0:00:04
#    - -------------------------------------- 0.7/15.9 MB 3.8 MB/s eta 0:00:05
#    -- ------------------------------------- 1.0/15.9 MB 4.4 MB/s eta 0:00:04
#    -- ------------------------------------- 1.2/15.9 MB 4.3 MB/s eta 0:00:04
#    --- ------------------------------------ 1.5/15.9 MB 4.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.7/15.9 MB 4.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 2.0/15.9 MB 4.5 MB/s eta 0:00:04
#    ----- ---------------------------------- 2.2/15.9 MB 4.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 2.2/15.9 MB 4.5 MB/s eta 0:00:04
#    ----- ---------------------------------- 2.3/15.9 MB 4.0 MB/s eta 0:00:04
#    ------ --------------------------------- 2.4/15.9 MB 3.8 MB/s eta 0:00:04
#    ------ --------------------------------- 2.5/15.9 MB 3.8 MB/s eta 0:00:04
#    ------- -------------------------------- 2.8/15.9 MB 3.9 MB/s eta 0:00:04
#    ------- -------------------------------- 2.9/15.9 MB 3.8 MB/s eta 0:00:04
#    -------- ------------------------------- 3.2/15.9 MB 3.9 MB/s eta 0:00:04
#    -------- ------------------------------- 3.3/15.9 MB 3.8 MB/s eta 0:00:04
#    -------- ------------------------------- 3.6/15.9 MB 3.9 MB/s eta 0:00:04
#    --------- ------------------------------ 3.7/15.9 MB 3.9 MB/s eta 0:00:04
#    --------- ------------------------------ 3.8/15.9 MB 3.8 MB/s eta 0:00:04
#    ---------- ----------------------------- 4.0/15.9 MB 3.8 MB/s eta 0:00:04
#    ---------- ----------------------------- 4.1/15.9 MB 3.8 MB/s eta 0:00:04
#    ---------- ----------------------------- 4.3/15.9 MB 3.7 MB/s eta 0:00:04
#    ---------- ----------------------------- 4.4/15.9 MB 3.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 4.5/15.9 MB 3.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 4.7/15.9 MB 3.7 MB/s eta 0:00:04
#    ------------ --------------------------- 5.0/15.9 MB 3.7 MB/s eta 0:00:03
#    ------------- -------------------------- 5.2/15.9 MB 3.8 MB/s eta 0:00:03
#    ------------- -------------------------- 5.4/15.9 MB 3.8 MB/s eta 0:00:03
#    -------------- ------------------------- 5.7/15.9 MB 3.9 MB/s eta 0:00:03
#    -------------- ------------------------- 5.9/15.9 MB 3.9 MB/s eta 0:00:03
#    --------------- ------------------------ 6.2/15.9 MB 4.0 MB/s eta 0:00:03
#    --------------- ------------------------ 6.3/15.9 MB 4.0 MB/s eta 0:00:03
#    ---------------- ----------------------- 6.7/15.9 MB 4.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 7.0/15.9 MB 4.1 MB/s eta 0:00:03
#    ------------------ --------------------- 7.2/15.9 MB 4.1 MB/s eta 0:00:03
#    ------------------ --------------------- 7.3/15.9 MB 4.1 MB/s eta 0:00:03
#    ------------------ --------------------- 7.5/15.9 MB 4.1 MB/s eta 0:00:03
#    ------------------- -------------------- 7.6/15.9 MB 4.1 MB/s eta 0:00:03
#    ------------------- -------------------- 7.7/15.9 MB 4.0 MB/s eta 0:00:03
#    ------------------- -------------------- 7.9/15.9 MB 4.0 MB/s eta 0:00:02
#    -------------------- ------------------- 8.2/15.9 MB 4.0 MB/s eta 0:00:02
#    --------------------- ------------------ 8.4/15.9 MB 4.1 MB/s eta 0:00:02
#    --------------------- ------------------ 8.5/15.9 MB 4.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 8.8/15.9 MB 4.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 9.0/15.9 MB 4.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 9.0/15.9 MB 4.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 9.2/15.9 MB 4.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 9.5/15.9 MB 4.0 MB/s eta 0:00:02
#    ------------------------ --------------- 9.7/15.9 MB 4.0 MB/s eta 0:00:02
#    ------------------------ --------------- 9.7/15.9 MB 4.0 MB/s eta 0:00:02
#    ------------------------- -------------- 10.0/15.9 MB 4.0 MB/s eta 0:00:02
#    ------------------------- -------------- 10.2/15.9 MB 4.0 MB/s eta 0:00:02
#    ------------------------- -------------- 10.3/15.9 MB 4.0 MB/s eta 0:00:02
#    -------------------------- ------------- 10.4/15.9 MB 4.0 MB/s eta 0:00:02
#    --------------------------- ------------ 10.8/15.9 MB 4.0 MB/s eta 0:00:02
#    --------------------------- ------------ 10.9/15.9 MB 4.0 MB/s eta 0:00:02
#    --------------------------- ------------ 11.0/15.9 MB 4.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 11.2/15.9 MB 4.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 11.5/15.9 MB 4.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.7/15.9 MB 4.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.9/15.9 MB 4.0 MB/s eta 0:00:02
#    ------------------------------ --------- 12.0/15.9 MB 3.9 MB/s eta 0:00:01
#    ------------------------------ --------- 12.1/15.9 MB 3.9 MB/s eta 0:00:01
#    ------------------------------- -------- 12.4/15.9 MB 3.9 MB/s eta 0:00:01
#    ------------------------------- -------- 12.5/15.9 MB 4.0 MB/s eta 0:00:01
#    ------------------------------- -------- 12.7/15.9 MB 4.0 MB/s eta 0:00:01
#    -------------------------------- ------- 12.8/15.9 MB 4.0 MB/s eta 0:00:01
#    -------------------------------- ------- 13.1/15.9 MB 4.0 MB/s eta 0:00:01
#    --------------------------------- ------ 13.3/15.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.6/15.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.7/15.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.8/15.9 MB 4.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.0/15.9 MB 4.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.2/15.9 MB 4.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.3/15.9 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------ --- 14.4/15.9 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------- -- 14.8/15.9 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------- -- 15.0/15.9 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------- -- 15.1/15.9 MB 4.1 MB/s eta 0:00:01
#    -------------------------------------- - 15.3/15.9 MB 4.1 MB/s eta 0:00:01
#    -------------------------------------- - 15.5/15.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  15.6/15.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.9 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  15.9/15.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  15.9/15.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  15.9/15.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 15.9/15.9 MB 3.8 MB/s eta 0:00:00
# Downloading pyproj-3.6.1-cp311-cp311-win_amd64.whl (6.1 MB)
#    ---------------------------------------- 0.0/6.1 MB ? eta -:--:--
#    - -------------------------------------- 0.2/6.1 MB 6.7 MB/s eta 0:00:01
#    -- ------------------------------------- 0.4/6.1 MB 5.3 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.8/6.1 MB 6.0 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.9/6.1 MB 5.2 MB/s eta 0:00:02
#    ------- -------------------------------- 1.2/6.1 MB 5.5 MB/s eta 0:00:01
#    --------- ------------------------------ 1.4/6.1 MB 5.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.6/6.1 MB 5.2 MB/s eta 0:00:01
#    ------------ --------------------------- 1.9/6.1 MB 5.2 MB/s eta 0:00:01
#    ------------ --------------------------- 2.0/6.1 MB 4.8 MB/s eta 0:00:01
#    -------------- ------------------------- 2.3/6.1 MB 5.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.5/6.1 MB 5.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.7/6.1 MB 4.9 MB/s eta 0:00:01
#    ------------------ --------------------- 2.8/6.1 MB 5.0 MB/s eta 0:00:01
#    ------------------- -------------------- 3.0/6.1 MB 4.8 MB/s eta 0:00:01
#    --------------------- ------------------ 3.3/6.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.5/6.1 MB 4.7 MB/s eta 0:00:01
#    ------------------------ --------------- 3.7/6.1 MB 4.7 MB/s eta 0:00:01
#    -------------------------- ------------- 4.0/6.1 MB 4.8 MB/s eta 0:00:01
#    --------------------------- ------------ 4.1/6.1 MB 4.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.4/6.1 MB 4.8 MB/s eta 0:00:01
#    ------------------------------ --------- 4.6/6.1 MB 4.8 MB/s eta 0:00:01
#    -------------------------------- ------- 4.9/6.1 MB 4.8 MB/s eta 0:00:01
#    --------------------------------- ------ 5.1/6.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.2/6.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.2/6.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.2/6.1 MB 4.8 MB/s eta 0:00:01
#    -------------------------------------- - 5.8/6.1 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  6.0/6.1 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  6.1/6.1 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 6.1/6.1 MB 4.4 MB/s eta 0:00:00
# Downloading shapely-2.0.6-cp311-cp311-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------ --------------------------------- 0.2/1.4 MB 6.7 MB/s eta 0:00:01
#    -------- ------------------------------- 0.3/1.4 MB 3.7 MB/s eta 0:00:01
#    ------------- -------------------------- 0.5/1.4 MB 3.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.6/1.4 MB 3.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.8/1.4 MB 3.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.4 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.2/1.4 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 1.4/1.4 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 3.5 MB/s eta 0:00:00
# Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
#    ---------------------------------------- 0.0/167.3 kB ? eta -:--:--
#    ---------------------------------------- 167.3/167.3 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: shapely, certifi, pyproj, pyogrio, geopandas
# Successfully installed certifi-2024.8.30 geopandas-1.0.1 pyogrio-0.9.0 pyproj-3.6.1 shapely-2.0.6
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\zaraa\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting geoplot
#   Downloading geoplot-0.5.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting matplotlib>=3.1.2 (from geoplot)
#   Downloading matplotlib-3.9.2-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting seaborn (from geoplot)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: pandas in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geoplot) (2.1.1)
# Requirement already satisfied: geopandas>=0.9.0 in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geoplot) (1.0.1)
# Collecting cartopy (from geoplot)
#   Downloading Cartopy-0.23.0-cp311-cp311-win_amd64.whl.metadata (8.2 kB)
# Collecting mapclassify>=2.1 (from geoplot)
#   Downloading mapclassify-2.8.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting contextily>=1.0.0 (from geoplot)
#   Downloading contextily-1.6.2-py3-none-any.whl.metadata (2.9 kB)
# Collecting geopy (from contextily>=1.0.0->geoplot)
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting mercantile (from contextily>=1.0.0->geoplot)
#   Downloading mercantile-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pillow in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from contextily>=1.0.0->geoplot) (10.0.1)
# Collecting rasterio (from contextily>=1.0.0->geoplot)
#   Downloading rasterio-1.3.11-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Collecting requests (from contextily>=1.0.0->geoplot)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: joblib in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from contextily>=1.0.0->geoplot) (1.3.2)
# Collecting xyzservices (from contextily>=1.0.0->geoplot)
#   Downloading xyzservices-2024.9.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: numpy>=1.22 in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geopandas>=0.9.0->geoplot) (1.26.0)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geopandas>=0.9.0->geoplot) (0.9.0)
# Requirement already satisfied: packaging in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geopandas>=0.9.0->geoplot) (24.1)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geopandas>=0.9.0->geoplot) (3.6.1)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geopandas>=0.9.0->geoplot) (2.0.6)
# Collecting networkx>=2.7 (from mapclassify>=2.1->geoplot)
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mapclassify>=2.1->geoplot) (1.3.1)
# Requirement already satisfied: scipy>=1.8 in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mapclassify>=2.1->geoplot) (1.11.3)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.1.2->geoplot)
#   Downloading contourpy-1.3.0-cp311-cp311-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.1.2->geoplot)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.1.2->geoplot)
#   Downloading fonttools-4.53.1-cp311-cp311-win_amd64.whl.metadata (165 kB)
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      ------------------------- ------------ 112.6/165.9 kB 3.3 MB/s eta 0:00:01
#      -------------------------------------- 165.9/165.9 kB 2.0 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.1.2->geoplot)
#   Downloading kiwisolver-1.4.7-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.1.2->geoplot)
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib>=3.1.2->geoplot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->geoplot) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas->geoplot) (2023.3)
# Collecting pyshp>=2.3 (from cartopy->geoplot)
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl.metadata (55 kB)
#      ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/56.0 kB ? eta -:--:--
#      ---------------------------------- --- 51.2/56.0 kB 525.1 kB/s eta 0:00:01
#      -------------------------------------- 56.0/56.0 kB 419.6 kB/s eta 0:00:00
# Requirement already satisfied: certifi in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyogrio>=0.7.2->geopandas>=0.9.0->geoplot) (2024.8.30)
# Requirement already satisfied: six>=1.5 in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.2->geoplot) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn>=1.0->mapclassify>=2.1->geoplot) (3.2.0)
# Collecting geographiclib<3,>=1.52 (from geopy->contextily>=1.0.0->geoplot)
#   Downloading geographiclib-2.0-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: click>=3.0 in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mercantile->contextily>=1.0.0->geoplot) (8.1.7)
# Collecting affine (from rasterio->contextily>=1.0.0->geoplot)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs (from rasterio->contextily>=1.0.0->geoplot)
#   Downloading attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting cligj>=0.5 (from rasterio->contextily>=1.0.0->geoplot)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting snuggs>=1.4.1 (from rasterio->contextily>=1.0.0->geoplot)
#   Downloading snuggs-1.4.7-py3-none-any.whl.metadata (3.4 kB)
# Collecting click-plugins (from rasterio->contextily>=1.0.0->geoplot)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\lib\site-packages (from rasterio->contextily>=1.0.0->geoplot) (65.5.0)
# Collecting charset-normalizer<4,>=2 (from requests->contextily>=1.0.0->geoplot)
#   Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests->contextily>=1.0.0->geoplot)
#   Downloading idna-3.8-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->contextily>=1.0.0->geoplot)
#   Downloading urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: colorama in c:\users\zaraa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click>=3.0->mercantile->contextily>=1.0.0->geoplot) (0.4.6)
# Downloading geoplot-0.5.1-py3-none-any.whl (28 kB)
# Downloading contextily-1.6.2-py3-none-any.whl (17 kB)
# Downloading mapclassify-2.8.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.9 kB ? eta -:--:--
#    ---------------------------------------- 58.9/58.9 kB 1.6 MB/s eta 0:00:00
# Downloading matplotlib-3.9.2-cp311-cp311-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#     --------------------------------------- 0.2/7.8 MB 4.6 MB/s eta 0:00:02
#    - -------------------------------------- 0.3/7.8 MB 3.3 MB/s eta 0:00:03
#    -- ------------------------------------- 0.4/7.8 MB 3.4 MB/s eta 0:00:03
#    --- ------------------------------------ 0.6/7.8 MB 2.9 MB/s eta 0:00:03
#    --- ------------------------------------ 0.7/7.8 MB 2.9 MB/s eta 0:00:03
#    --- ------------------------------------ 0.8/7.8 MB 2.7 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.0/7.8 MB 2.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.1/7.8 MB 2.9 MB/s eta 0:00:03
#    ------ --------------------------------- 1.3/7.8 MB 3.0 MB/s eta 0:00:03
#    ------- -------------------------------- 1.4/7.8 MB 2.9 MB/s eta 0:00:03
#    -------- ------------------------------- 1.6/7.8 MB 2.9 MB/s eta 0:00:03
#    -------- ------------------------------- 1.7/7.8 MB 2.8 MB/s eta 0:00:03
#    --------- ------------------------------ 2.0/7.8 MB 3.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/7.8 MB 3.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.2/7.8 MB 3.0 MB/s eta 0:00:02
#    ------------ --------------------------- 2.4/7.8 MB 3.1 MB/s eta 0:00:02
#    ------------ --------------------------- 2.5/7.8 MB 2.9 MB/s eta 0:00:02
#    ------------- -------------------------- 2.6/7.8 MB 3.0 MB/s eta 0:00:02
#    -------------- ------------------------- 2
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Installing collected packages: xyzservices, urllib3, pyshp, pyparsing, networkx, kiwisolver, idna, geographiclib, fonttools, cycler, contourpy, charset-normalizer, attrs, affine, snuggs, requests, mercantile, matplotlib, geopy, cligj, click-plugins, seaborn, rasterio, mapclassify, cartopy, contextily, geoplot
# Successfully installed affine-2.4.0 attrs-24.2.0 cartopy-0.23.0 charset-normalizer-3.3.2 click-plugins-1.1.1 cligj-0.7.2 contextily-1.6.2 contourpy-1.3.0 cycler-0.12.1 fonttools-4.53.1 geographiclib-2.0 geoplot-0.5.1 geopy-2.4.1 idna-3.8 kiwisolver-1.4.7 mapclassify-2.8.0 matplotlib-3.9.2 mercantile-1.2.1 networkx-3.3 pyparsing-3.1.4 pyshp-2.3.1 rasterio-1.3.11 requests-2.32.3 seaborn-0.13.2 snuggs-1.4.7 urllib3-2.2.2 xyzservices-2024.9.0
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\zaraa\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# install geopandas and geoplot:
# conda install geopandas
# conda install -c conda-forge geoplot
import geopandas
import geoplot
import pandas as pd
import numpy as np
from shapely.geometry import Point, Polygon
import matplotlib.pyplot as plt

# %%
# Lets find the most exensive type of rooms. 

df = pd.read_csv('data/listings_ZD.csv')

dfrm = df.groupby('room_type')['price'].mean()
dfrm.reset_index()
dfrm.plot(kind='bar', x='room_type', y='price')
# Out:
# <Axes: xlabel='room_type'>

# %%
dfrm.plot(kind='barh', x='room_type', y='price')
# Out:
# <Axes: ylabel='room_type'>

# %%
df = pd.read_csv('data/listings_ZD.csv')

dfrm = df.groupby('room_type')['price'].agg(['mean', 'std', 'count'])
# Get the square root of the sample size
dfrm['sqrt_count'] = np.sqrt(dfrm['count'])

# get the standard devation of the mean
dfrm['std_of_mean'] = dfrm['std'] / dfrm['sqrt_count']

# two stds below the mean
dfrm['lower_bound'] = dfrm['mean'] - (2 *dfrm['std_of_mean'])

# two stds above the mean
dfrm['upper_bound'] = dfrm['mean'] + (2 *dfrm['std_of_mean'])
dfrm = dfrm.round()
dfrm
# Out:
#                   mean    std  count  sqrt_count  std_of_mean  lower_bound  \
# room_type
# Bungaloo           4.0    NaN      1         1.0          NaN          NaN
# Entire home/apt  199.0  338.0  23998       155.0          2.0        195.0
# Hotel room       275.0  302.0    398        20.0         15.0        245.0
# Penthouse        690.0    NaN      1         1.0          NaN          NaN
# Private room      91.0  282.0  21144       145.0          2.0         88.0
# Shared room       87.0  354.0    987        31.0         11.0         65.0
#
#                  upper_bound
# room_type
# Bungaloo                 NaN
# Entire home/apt        204.0
# Hotel room             305.0
# Penthouse                NaN
# Private room            95.0
# Shared room            110.0

# %%
# Import listings
df=pd.read_csv('data/listings.csv')

# %% [markdown]
# # Basic Analytics

# %% [markdown]
# ### Basic Inference
#
# 1. What do mean, standard deviation and standard deviation of the mean, ... mean(?)

# %% [markdown]
# #### Types of Mean
# 1.  arithmetic:  $\overline{a}_{\mathrm{ar}} = { \sum_{i=1}^{N} a_i \over N }$
# 2.  geometric:  $\overline{a}_{\mathrm{geo}} = \left( { \prod_{i=1}^{N} a_i  }\right)^{1 \over N}$
# 3.  harmonic:  $ { 1\over \overline{a}_{\mathrm{har}} } =  { \sum_{i=1}^{N} { 1 \over a_i} \over N } $

# %%
# Standard deviation of the mean 
# If we take an N sized sample, what will it look like?

# this generates a sample of normal data to serve as out population
mu, sigma = 0, 1 # mean and standard deviation
population = np.random.normal(mu, sigma, 10000)
plt.hist(population)
# Out:
# (array([  22.,  186.,  820., 1877., 2792., 2550., 1286.,  390.,   67.,
#           10.]),
#  array([-3.55258056, -2.80786711, -2.06315366, -1.31844021, -0.57372676,
#          0.17098669,  0.91570014,  1.66041359,  2.40512704,  3.14984049,
#          3.89455394]),
#  <BarContainer object of 10 artists>)

# %%
# repeatedly sample
import random 
sqrt_N = 10
N = sqrt_N*sqrt_N
mean_list = []
stdev_list = []


for i in range(1,1000):
    random.shuffle(population)
    sample = population[:N]
    # sample = np.random.normal(mu, sigma, N)
    mean_list.append(sample.mean())
    stdev_list.append(sample.std())

# %%
dfm = pd.DataFrame(mean_list, columns=['mean'])
dfm.plot.hist()

dfstd = pd.DataFrame(stdev_list, columns=['mean'])
dfstd.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #### sample statistics
#
# * mean of the sample mean
# $$
# \mu_\mathrm{sm} \approx \mu_\mathrm{pop}
# $$
# * std of the mean:
# $$
# \sigma_\mathrm{sm}  \approx { \sigma_\mathrm{pop} \over \sqrt{N} }
# $$

# %%
np.mean(mean_list), np.std(mean_list) , 1/np.std(mean_list)
# Out:
# (-0.015581086564847241, 0.09807524596176984, 10.196252787271158)

# %% [markdown]
# # Tableau Prep

# %% [markdown]
# ### AirBnB Buroughs Map

# %%
#  We are going to make a map of all of the AirBNB properties. Later we do this in Tableau

cols_to_keep=['longitude','latitude']

crs={'init':'epsg:4326'}

boroughs = geopandas.read_file(geoplot.datasets.get_path('nyc_boroughs'))
geom = geopandas.points_from_xy(df["longitude"], df["latitude"])
geo_df=geopandas.GeoDataFrame(df, crs=crs,geometry=geom)

fig,ax=plt.subplots(figsize=(9,9))
fig.suptitle('Map of Listings, Colored by Borough', fontsize=20)
boroughs.plot(ax=ax,alpha=0.4,color="grey")
geo_df[geo_df['neighbourhood_group']=="Bronx"].plot(ax=ax,markersize=4, alpha=0.4,color="blue", label="Bronx")
geo_df[geo_df['neighbourhood_group']=="Manhattan"].plot(ax=ax,markersize=4, alpha=0.4,color="red", label="Manhattan")
geo_df[geo_df['neighbourhood_group']=="Queens"].plot(ax=ax,markersize=4, alpha=0.4,color="aqua", label="Queens")
geo_df[geo_df['neighbourhood_group']=="Brooklyn"].plot(ax=ax,markersize=4, alpha=0.4,color="orange", label="Brooklyn")
geo_df[geo_df['neighbourhood_group']=="Staten Island"].plot(ax=ax,markersize=4, alpha=0.4,color="green", label="Staten Island")
plt.legend()
# Out:
# C:\Users\zaraa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %% [markdown]
# ### Histograms

# %%
# Now we make a set of price histograms

import matplotlib.pyplot as plt
import numpy as np

from matplotlib import colors
from matplotlib.ticker import PercentFormatter

n_bins = 20

# price data to make histograms with

price_filter = df['price']<=500

neighborhood_filter = df['neighbourhood_group']=="Bronx"
bronx = df[neighborhood_filter & price_filter].price

neighborhood_filter = df['neighbourhood_group']=="Brooklyn"
brooklyn = df[neighborhood_filter & price_filter].price

neighborhood_filter = df['neighbourhood_group']=="Manhattan"
manhattan = df[neighborhood_filter & price_filter].price

neighborhood_filter = df['neighbourhood_group']=="Queens"
queens = df[neighborhood_filter & price_filter].price

neighborhood_filter = df['neighbourhood_group']=="Staten Island"
staten = df[neighborhood_filter & price_filter].price

fig, axs = plt.subplots(5, 1, sharey=True, sharex=True, tight_layout=True)

# sefault figsize is  6.4 X 4.8 inches.  we need someting taller
fig.set_size_inches(8, 12.0)

fig.suptitle('Price Histogram by Borough', fontsize=20)
# We can set the number of bins with the *bins* keyword argument.
axs[0].hist(bronx, bins=n_bins, color = 'blue', density=True)
axs[1].hist(brooklyn, bins=n_bins, color = 'orange', density=True)
axs[2].hist(manhattan, bins=n_bins, color = 'red', density=True)
axs[3].hist(queens, bins=n_bins, color = 'aqua', density=True)
axs[4].hist(staten, bins=n_bins, color = 'green', density=True)
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right')

# %%
# df.plot(kind='hist', x='price', subplots=True )

# cheap[['price', 'neighbourhood_group']].plot(kind='hist', subplots=True )

# %%
cheap_df = df[df.price <= 500]
cheap_df.hist(
    column='price', 
    by='neighbourhood_group', 
    figsize=(5,13), 
    layout=(7,1), 
    sharex=True, 
    sharey=True
    )
# Out:
# array([<Axes: title={'center': 'Bronx'}>,
#        <Axes: title={'center': 'Brooklyn'}>,
#        <Axes: title={'center': 'Manhattan'}>,
#        <Axes: title={'center': 'Queens'}>,
#        <Axes: title={'center': 'Staten Island'}>, <Axes: >, <Axes: >],
#       dtype=object)

# %% [markdown]
# ### Box and Whisker

# %%
# Finally we make some "Box and Whisker"  Plots, using IQR for the boxes and whiskers

price_filter = (df['price']<=10000) &  (df['price']>=1)

neighborhood_filter = df['neighbourhood_group']=="Bronx"
bronx = df[neighborhood_filter & price_filter].price

neighborhood_filter = df['neighbourhood_group']=="Brooklyn"
brooklyn = df[neighborhood_filter & price_filter].price

neighborhood_filter = df['neighbourhood_group']=="Manhattan"
manhattan = df[neighborhood_filter & price_filter].price

neighborhood_filter = df['neighbourhood_group']=="Queens"
queens = df[neighborhood_filter & price_filter].price

neighborhood_filter = df['neighbourhood_group']=="Staten Island"
staten = df[neighborhood_filter & price_filter].price

box_weights = [bronx,brooklyn, manhattan, queens, staten]
labels = ['Bronx','Brooklyn', 'Manhattan', 'Queens', 'Staten Island']
colors = ['blue', 'orange', 'red', 'aqua', 'green']
fig, ax = plt.subplots()

fig.set_size_inches(5, 7.0)

fig.suptitle('Box and Whisker', fontsize=20)
ax.set_ylabel('price')
ax.set_yscale('log')
bplot = ax.boxplot(box_weights,
                   patch_artist=True)  # will be used to label x-ticks
ax.set_xticklabels(labels) 
for patch, color in zip(bplot['boxes'], colors):
    patch.set_facecolor(color)

# %%
# in tableau, be sure to copy price and disaggregate it to match this plot

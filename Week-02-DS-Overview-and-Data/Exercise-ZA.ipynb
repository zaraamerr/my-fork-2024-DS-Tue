# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import here.
import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Food choices data set into a variable (e.g., df_food).

food_data_set_path = 'data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
rows, cols = df_food.shape
print(f"Total number of rows: {rows}")
print(f"Total number of cols: {cols}")
# Out:
# Total number of rows: 125
# Total number of cols: 61

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
for col in df_food.columns:
    print(f"{col}, Type: {df_food[col].dtype}")
# Out:
# GPA, Type: object
# Gender, Type: int64
# breakfast, Type: int64
# calories_chicken, Type: int64
# calories_day, Type: float64
# calories_scone, Type: float64
# coffee, Type: int64
# comfort_food, Type: object
# comfort_food_reasons, Type: object
# comfort_food_reasons_coded, Type: float64
# cook, Type: float64
# comfort_food_reasons_coded.1, Type: int64
# cuisine, Type: float64
# diet_current, Type: object
# diet_current_coded, Type: int64
# drink, Type: float64
# eating_changes, Type: object
# eating_changes_coded, Type: int64
# eating_changes_coded1, Type: int64
# eating_out, Type: int64
# employment, Type: float64
# ethnic_food, Type: int64
# exercise, Type: float64
# father_education, Type: float64
# father_profession, Type: object
# fav_cuisine, Type: object
# fav_cuisine_coded, Type: int64
# fav_food, Type: float64
# food_childhood, Type: object
# fries, Type: int64
# fruit_day, Type: int64
# grade_level, Type: int64
# greek_food, Type: int64
# healthy_feeling, Type: int64
# ...

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns?

# %%
# Remove ‘em.
select_cols = ['calories_day', 'weight', 'Gender']
new_df = df_food[select_cols]
new_df
# Out:
#      calories_day                    weight  Gender
# 0             NaN                       187       2
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# ..            ...                       ...     ...
# 120           4.0                       156       1
# 121           2.0                       180       1
# 122           NaN                       120       1
# 123           4.0                       135       2
# 124           NaN                       135       1
#
# [125 rows x 3 columns]

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.
new_df.isna().sum()
# Out:
# calories_day    19
# weight           2
# Gender           0
# dtype: int64

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em.
clean_df = new_df.dropna()

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that.
clean_df = clean_df.copy()
clean_df.loc[:, 'weight'] = pd.to_numeric(clean_df['weight'], errors='coerce')
clean_df.dropna(subset=['weight'], inplace=True)
clean_df
# Out:
#      calories_day weight  Gender
# 1             3.0  155.0       1
# 4             2.0  190.0       1
# 5             3.0  190.0       1
# 6             3.0  180.0       2
# 7             3.0  137.0       1
# ..            ...    ...     ...
# 118           3.0  140.0       1
# 119           3.0  185.0       2
# 120           4.0  156.0       1
# 121           2.0  180.0       1
# 123           4.0  135.0       2
#
# [101 rows x 3 columns]

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!
clean_df.to_csv('data/cleaned_food_coded.csv', index=False)

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a variable (e.g., df_salary).
df_salary = pd.read_csv('data/ask_a_manager_salary_survey.tsv', sep ="\t")
df_salary
# Out:
#                 Timestamp How old are you?  What industry do you work in?  \
# 0      4/27/2021 11:02:10            25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22            25-34              Computing or Tech
# 2      4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41            25-34                     Nonprofits
# 4      4/27/2021 11:02:42            25-34  Accounting, Banking & Finance
# ...                   ...              ...                            ...
# 28057  7/12/2024 22:52:01            35-44                    Health care
# 28058  7/23/2024 17:51:03            25-34              Computing or Tech
# 28059  7/24/2024 12:22:58            18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45            18-24              Computing or Tech
# 28061   8/20/2024 1:06:13            25-34                    Health care
#
#                                       Job title  \
# ...

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# #### rename the file to something that is better for all systems.
# * No spaces in filename (can use '_')
# * all lower case

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.
rows, cols = df_salary.shape
print(f"Total number of rows: {rows}")
print(f"Total number of cols: {cols}")
# Out:
# Total number of rows: 28062
# Total number of cols: 18

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.
for col in df_salary.columns:
    print(f"{col}, Type: {df_salary[col].dtype}")
# Out:
# Timestamp, Type: object
# How old are you?, Type: object
# What industry do you work in?, Type: object
# Job title, Type: object
# If your job title needs additional context, please clarify here:, Type: object
# What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.), Type: object
# How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits., Type: float64
# Please indicate the currency, Type: object
# If "Other," please indicate the currency here: , Type: object
# If your income needs additional context, please provide it here:, Type: object
# What country do you work in?, Type: object
# If you're in the U.S., what state do you work in?, Type: object
# ...

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race

new_colnames = ['timestamp', 'age', 'industry', 'title', 'title_context', 'salary', 'additional_compensation', 'currency', 'other_currency', 'salary_context', 'country', 'state', 'city', 'total_yoe', 'field_yoe', 'highest_education', 'gender', 'race']
df_salary.columns = new_colnames
df_salary
# Out:
#                 timestamp    age                       industry  \
# 0      4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1      4/27/2021 11:02:22  25-34              Computing or Tech
# 2      4/27/2021 11:02:38  25-34  Accounting, Banking & Finance
# 3      4/27/2021 11:02:41  25-34                     Nonprofits
# 4      4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# ...                   ...    ...                            ...
# 28057  7/12/2024 22:52:01  35-44                    Health care
# 28058  7/23/2024 17:51:03  25-34              Computing or Tech
# 28059  7/24/2024 12:22:58  18-24  Accounting, Banking & Finance
# 28060  7/26/2024 11:20:45  18-24              Computing or Tech
# 28061   8/20/2024 1:06:13  25-34                    Health care
#
#                                           title title_context   salary  \
# 0            Research and Instruction Librarian           NaN   55,000
# ...

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.
df_salary['industry'].value_counts()
# Out:
# industry
# Computing or Tech                          4699
# Education (Higher Education)               2464
# Nonprofits                                 2419
# Health care                                1896
# Government and Public Administration       1889
#                                            ...
# Gaming (Gambling)                             1
# Regulatory Affairs- nutraceuticals            1
# Manufacturing : corporate admin support       1
# Real Estate Investment Support                1
# Wine & Spirits                                1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new dataframe.

# %%
# Filtery filter. (Save it to a new variable, df_salary_tech.)
df_salary_tech = df_salary[df_salary['industry'] == 'Computing or Tech']

# %% [markdown]
# Do a sanity check to make sure that the only values you kept are the one you are filtered for.

# %%
# Sanity Check 

df_salary_tech
# Out:
#                 timestamp    age           industry  \
# 1      4/27/2021 11:02:22  25-34  Computing or Tech
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28050   7/1/2024 13:38:46  25-34  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# 28058  7/23/2024 17:51:03  25-34  Computing or Tech
# 28060  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                               title  \
# 1          Change & Internal Communications Manager
# 8                                   Systems Analyst
# 43                      Principal Software Engineer
# 44                             Intelligence Analyst
# 46                                 Mobile developer
# ...

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter for just the jobs that pay in USD!
df_salary_tech = df_salary_tech[df_salary_tech['currency'] == 'USD']
df_salary_tech
# Out:
#                 timestamp    age           industry  \
# 8      4/27/2021 11:03:01  45-54  Computing or Tech
# 43     4/27/2021 11:04:04  25-34  Computing or Tech
# 44     4/27/2021 11:04:04  25-34  Computing or Tech
# 46     4/27/2021 11:04:07  35-44  Computing or Tech
# 47     4/27/2021 11:04:09  35-44  Computing or Tech
# ...                   ...    ...                ...
# 28044   6/3/2024 16:15:43  18-24  Computing or Tech
# 28051   7/1/2024 20:05:58  25-34  Computing or Tech
# 28052   7/3/2024 14:02:01  25-34  Computing or Tech
# 28058  7/23/2024 17:51:03  25-34  Computing or Tech
# 28060  7/26/2024 11:20:45  18-24  Computing or Tech
#
#                                         title                 title_context  \
# 8                             Systems Analyst  Data developer/ETL Developer
# 43                Principal Software Engineer                           NaN
# 44                       Intelligence Analyst                           NaN
# ...

# %% [markdown]
# What we really want know is how each U.S. city pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.
df_salary_tech['country'].value_counts()
# Out:
# country
# United States               1576
# USA                         1222
# US                           412
# U.S.                         108
# United States of America      90
#                             ...
# Pakistan                       1
# Puerto Rico                    1
# America                        1
# Uniyed states                  1
# Burma                          1
# Name: count, Length: 76, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all with 'US'.
df_salary_tech.loc[:,'country'] = df_salary_tech['country'].replace({'United States' : 'US', 'USA' : 'US', 'U.S.' : 'US', 'United States of America' : 'US'})

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.
df_salary_tech['country'].value_counts()
# Out:
# country
# US                3408
# United States       68
# Usa                 59
# USA                 56
# usa                 28
#                   ...
# Mexico               1
# United Stateds       1
# ISA                  1
# singapore            1
# Burma                1
# Name: count, Length: 72, dtype: int64

# %% [markdown]
# Did you notice anything interesting?

# %%
# BONUS CREDIT: resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.
df_salary_tech['country'].unique()
countries_that_are_not_us = ['Australia', 'Cuba', 'Danmark', 'Canada', 'Italy', 'International ', 'Israel', 'India', 'Remote (philippines)', 'Singapore', 'Spain', 'Uruguay', 'Brazil', 'Mexico', 'United Kingdom', 'Canada ', 'singapore', 'Pakistan', 'New Zealand', 'Poland', 'France', 'Netherlands', 'China', 'San Francisco', 'Romania', 'Japan', 'Australian ', 'Denmark', 'Jamaica', 'Thailand', 'Colombia', 'denmark', 'Ghana', 'Nigeria ', 'ss', 'Nigeria', 'Burma']
not_us = df_salary_tech['country'].isin(countries_that_are_not_us)
df_salary_tech.loc[~not_us, 'country'] = 'US'

# %%
# BONUS CREDIT: if you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.
df_salary_tech['country'].value_counts()
# Out:
# country
# US                      3725
# Israel                     5
# Canada                     4
# Spain                      2
# France                     2
# Poland                     2
# Australia                  2
# United Kingdom             2
# Brazil                     2
# New Zealand                2
# India                      2
# Singapore                  1
# Romania                    1
# Nigeria                    1
# ss                         1
# Nigeria                    1
# Ghana                      1
# denmark                    1
# Colombia                   1
# Thailand                   1
# Jamaica                    1
# Denmark                    1
# Australian                 1
# Japan                      1
# San Francisco              1
# Remote (philippines)       1
# China                      1
# Netherlands                1
# Cuba                       1
# Danmark                    1
# Italy                      1
# ...

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.

gb = df_salary_tech.groupby('state')
gb['salary'].agg( ['min', 'mean', 'max'] )

#doesnt work!!!
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\groupby\groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# ...

# %% [markdown]
# Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed.

# %%
# Fix it.
df_salary_tech.loc[:, 'salary'] = pd.to_numeric(df_salary_tech['salary'], errors='coerce')

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!
gb = df_salary_tech.groupby('state')['salary'].agg(['min', 'mean', 'max'])
gb
# Out:
#                                     min           mean       max
# state
# Alabama                         35000.0  117400.000000  350000.0
# Alabama, District of Columbia       NaN            NaN       NaN
# Alabama, Montana                    NaN            NaN       NaN
# Alaska                              NaN            NaN       NaN
# Arizona                         35000.0   97833.333333  145000.0
# ...                                 ...            ...       ...
# Vermont                         91250.0  105625.000000  120000.0
# Virginia                        58750.0  115086.696970  378000.0
# Washington                         72.0  136923.916667  300000.0
# West Virginia                  120000.0  120000.000000  120000.0
# Wisconsin                           1.0  145806.888889  920000.0
#
# [66 rows x 3 columns]

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.
df_salary_tech.loc[:,'datetime'] = pd.to_datetime(df_salary_tech['timestamp'])

solely_22 = df_salary_tech['datetime'].dt.year == 2022

df_salary_tech_22 = df_salary_tech[solely_22]

gb = df_salary_tech_22.groupby('state')

gb['salary'].agg( ['min', 'mean', 'max'] )
# Out:
#                                   min           mean       max
# state
# Arizona                      101000.0  101000.000000  101000.0
# California                   111000.0  154060.000000  210000.0
# Colorado                      55000.0   55000.000000   55000.0
# Georgia                       91000.0  113333.333333  125000.0
# Illinois                      87000.0  116333.333333  132000.0
# Indiana                       90000.0   90000.000000   90000.0
# Kansas                       167000.0  167000.000000  167000.0
# Maryland                      62000.0   62000.000000   62000.0
# Massachusetts                 72000.0  112500.000000  153000.0
# Michigan, Texas, Washington  340000.0  340000.000000  340000.0
# New York                      14000.0  212320.000000  590000.0
# North Carolina                72000.0   72000.000000   72000.0
# Oregon                       120000.0  120000.000000  120000.0
# Texas                         10700.0   79566.666667  138000.0
# ...

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)
